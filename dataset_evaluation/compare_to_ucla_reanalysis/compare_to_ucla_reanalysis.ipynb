# %%
# could compare HMA water year 2016? 2017 actually!!!! https://nsidc.org/data/hma_sr_d/versions/1

# %%
import earthaccess

# %%
auth = earthaccess.login()

# %%
results = earthaccess.search_data(
    short_name="HMA_SR_D.001",
    cloud_hosted=True,
    #temporal=("2019-01", "2019-02"),
    #polygon=[(-100, 40), (-110, 40), (-105, 38), (-100, 40)],
)
results[0]
